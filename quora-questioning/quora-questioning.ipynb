# %% [markdown]
# # Quora Question Pairs.
# ## By Aschwin Schilperoort
#
# link: https://www.kaggle.com/c/quora-question-pairs/
#
# The goal of this competition is to predict which of the provided pairs of questions contain two questions with the same meaning. The ground truth is the set of labels that have been supplied by human experts. The ground truth labels are inherently subjective, as the true meaning of sentences can never be known with certainty. Human labeling is also a 'noisy' process, and reasonable people will disagree. As a result, the ground truth labels on this dataset should be taken to be 'informed' but not 100% accurate, and may include incorrect labeling. We believe the labels, on the whole, to represent a reasonable consensus, but this may often not be true on a case by case basis for individual items in the dataset.
#
# **Data fields**
# - id - the id of a training set question pair
# - qid1, qid2 - unique ids of each question (only available in train.csv)
# - question1, question2 - the full text of each question
# - is_duplicate - the target variable, set to 1 if question1 and question2 have essentially the same meaning, and 0 otherwise.
#
# Let's take a look at what we have!

# %%
# importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\1asch\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# importing the train & test dataset
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
print(train.head())
print(test.head())
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  What is the step by step guide to invest in sh...
# 1   1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2   2     5     6  How can I increase the speed of my internet co...
# 3   3     7     8  Why am I mentally very lonely? How can I solve...
# 4   4     9    10  Which one dissolve in water quikly sugar, salt...
#
#                                            question2  is_duplicate
# 0  What is the step by step guide to invest in sh...             0
# 1  What would happen if the Indian government sto...             0
# 2  How can Internet speed be increased by hacking...             0
# 3  Find the remainder when [math]23^{24}[/math] i...             0
# 4            Which fish would survive in salt water?             0
#    test_id                                          question1  \
# 0        0  How does the Surface Pro himself 4 compare wit...
# 1        1  Should I have a hair transplant at age 24? How...
# 2        2  What but is the best way to send money from Ch...
# 3        3                        Which food not emulsifiers?
# 4        4                   How "aberystwyth" start reading?
#
#                                            question2
# 0  Why did Microsoft choose core m3 and not core ...
# 1        How much cost does hair transplant require?
# 2                      What you send money to China?
# 3                                  What foods fibre?
# 4                     How their can I start reading?

# %% [markdown]
# So we can see we have two datasets train & test which contains questions asked on Quora. The problem is some of these questions are duplicates. So some questions are exactly the same as questions asked before. Repost alert!!! Now our goal is to find these duplicates, not by hand, but with the machines!
#
# To have a machine learn what the text says and to calculate it's a duplicate we have to clean the data first. We have to:
#
# - Remove numbers & punctuation!
# - Remove stems!
# - Remove stopwords!
#
#
# After this we can make a bag of words model on which we can train a model to correctly classify duplicate questions! Let's start of by cleaning the dataset.
#
# ## Cleaning the dataset

# %%
corpus = [[0]*2]
for i in range(0, 1000):
    question1 = re.sub('[^a-zA-Z]', ' ', train['question1'][i])
    question2 = re.sub('[^a-zA-Z]', ' ', train['question2'][i])
    question1 = question1.lower()
    question2 = question2.lower()
    question1 = question1.split()
    question2 = question2.split()
    ps = PorterStemmer()
    question1 = [ps.stem(word) for word in question1 if not word in set(stopwords.words('english'))]
    question2 = [ps.stem(word) for word in question2 if not word in set(stopwords.words('english'))]
    question1 = ' '.join(question1)
    question2 = ' '.join(question2)
    corpus.append([question1, question2])

# %%
corpus
# Out:
# [[0, 0],
#  ['step step guid invest share market india',
#   'step step guid invest share market'],
#  ['stori kohinoor koh noor diamond',
#   'would happen indian govern stole kohinoor koh noor diamond back'],
#  ['increas speed internet connect use vpn', 'internet speed increas hack dn'],
#  ['mental lone solv', 'find remaind math math divid'],
#  ['one dissolv water quikli sugar salt methan carbon di oxid',
#   'fish would surviv salt water'],
#  ['astrolog capricorn sun cap moon cap rise say',
#   'tripl capricorn sun moon ascend capricorn say'],
#  ['buy tiago', 'keep childern activ far phone video game'],
#  ['good geologist', 'great geologist'],
#  ['use instead', 'use instead'],
#  ['motorola compani hack charter motorolla dcx',
#   'hack motorola dcx free internet'],
#  ['method find separ slit use fresnel biprism',
#   'thing technician tell durabl reliabl laptop compon'],
#  ['read find youtub comment', 'see youtub comment'],
#  ['make physic easi learn', 'make physic easi learn'],
#  ['first sexual experi like', 'first sexual experi'],
#  ['law chang statu student visa green card us compar immigr law canada',
#   'law chang statu student visa green card us compar immigr law japan'],
#  ['would trump presid mean current intern master student f visa',
#   'trump presid affect student present us plan studi us'],
#  ['manipul mean', 'manipul mean'],
#  ['girl want friend guy reject', 'guy feel reject girl'],
#  ['mani quora user post question readili answer googl',
#   'peopl ask quora question answer easili googl'],
#  ['best digit market institut banglor', 'best digit market institut pune'],
#  ['rocket look white', 'rocket booster paint white'],
#  ['caus someon jealou', 'avoid jealou someon'],
#  ['question ask quora', 'question ask quora'],
#  ['much kv hp', 'find convers chart cc horsepow'],
#  ['mean everi time look clock number', 'mani time day clock hand overlap'],
#  ['tip make job interview process medicin',
#   'tip make job interview process foundat medicin'],
#  ['web applic', 'web applic framework'],
#  ['societi place much import sport', 'sport contribut societi'],
#  ['best way make money onlin', 'best way ask money onlin'],
#  ['prepar ca final law', 'one know complet prepar ca final exam'],
#  ['one thing would like better', 'one thing despit know better'],
#  ['special care someon nose get stuffi night', 'keep nose get stuffi night'],
#  ['game throne villain would like give merci',
#   'game throne villain would like merci'],
#  ['unit state govern still blacklist employ etc unit state citizen polit view',
#   'averag speed ga molecul determin'],
#  ['best travel websit spain', 'best travel websit'],
#  ['peopl think obama tri take gun away',
#   'gun control initi take away gun peopl alreadi'],
#  ['year old improv skill becom entrepreneur next year',
#   'year old guy becom billionair next year'],
#  ['girlfriend ask boyfriend choos make want one repli',
#   'girlfriend said end confus feel wish well disconnect call ask want get back togeth'],
#  ['prepar upsc', 'prepar civil servic'],
#  ['stall speed aoa f wing fulli swept back',
#   'aircraft stop use variabl sweep wing like f'],
#  ['slav squat', 'squat make leg thicker'],
#  ['expect cogniz confirm mail', 'expect cogniz confirm mail'],
#  ['make month day trade', 'make month day trade'],
#  ['good kid rebel worth long run', 'bore good kid'],
#  ['univers rexnord recruit new grad major look',
#   'univers b g food recruit new grad major look'],
#  ['quickest way increas instagram follow', 'increas number instagram follow'],
#  ['darth vader fought darth maul star war legend',
#   'quora charact limit profil descript'],
#  ['stage break coupl mean happen break emot whether male femal',
#   'affect breakup boy girl'],
#  ['exampl product make crude oil', 'product made crude oil'],
#  ['make friend', 'make friend'],
#  ['career launcher good rbi grade b prepar',
#   'career launcher onlin program rbi grade b'],
#  ['blu ray play regular dvd player', 'play blu ray dvd regular dvd player'],
#  ['nd alway sad', 'aerodynam happen propellor rotat'],
#  ['best memor thing ever eaten', 'delici dish ever eaten'],
#  ['gst affect ca tax offic', 'homework'],
#  ['difficult get rsi', 'appli program like rsi rise senior'],
#  ['israil friend', 'boyfriend lie true feel friend secretli attract'],
#  ['good rap song danc', 'best rap song'],
#  ['suddenli log gmail rememb gmail password realiz recoveri email longer aliv',
#   'rememb gmail password recoveri email recov e mail'],
#  ['best way learn french', 'learn french gender'],
#  ['download content kickass torrent without registr',
#   'kickass torrent trustworthi'],
#  ['normal dark ring around iri eye', 'caus dark ring around iri treat'],
#  ['new harri potter book harri potter curs child', 'bad new book j k rowl'],
#  ['alway get depress', 'alway get depress even'],
#  ['find european famili offic databas', 'find u famili offic databas'],
#  ['java program learn java program languag', 'learn comput languag like java'],
#  ['best book ever made', 'import book ever read'],
#  ['ever store energi produc lightn', 'possibl store energi lightn'],
#  ['review perform test', 'perform test'],
#  ['cost much privaci germani come els lost gain much privaci',
#   'peopl genuin enjoy salad dress'],
#  ['type immun', 'differ type immun bodi'],
#  ['narcissist person disord', 'narcissist person disord'],
#  ['speak english fluentli', 'learn speak english fluentli'],
#  ['help quickbook auto data recoveri support phone number recov corrupt data file',
#   'quickbook custom support phone number usa'],
#  ['richest gambler time reach level',
#   'richest gambler time reach level gambler'],
#  ['fire bullet backward aircraft go faster bullet bullet go backward',
#   'bullet travel faster speed sound shot gun possibl gun much devast occur'],
#  ['prevent breast cancer', 'breast cancer prevent'],
#  ['log gmail account friend phone',
#   'know log gmail account tell ip address devic name'],
#  ['make money internet', 'differ way make money onlin exclud sell thing'],
#  ['purpos life', 'purpos life life actual'],
#  ['bjp govern strip muslim christian indian citizenship put boat like rohingya burma',
#   'india appli burma rohingya model deport illeg bangladeshi'],
#  ['right etiquett wish jehovah wit happi birthday',
#   'import first person wish someon happi birthday'],
#  ['someon want open commerci fm radio station citi india much cost procedur',
#   'want make travel commerci clip video hd india new zealand much cost'],
#  ['swiss despis asian', 'technic employe despis sale peopl much'],
#  ['high salari incom job field biotechnolog',
#   'high pay job fresher tech biotechnolog'],
#  ['increas height also', 'height increas'],
#  ['major effect cambodia earthquak effect compar kamchatca earthquak',
#   'major effect cambodia earthquak effect compar valparaiso earthquak'],
#  ['differ sincer fair', 'differ honest sincer'],
#  ['best game laptop k inr', 'best game laptop rs'],
#  ['review next warrior prove ground part',
#   'review next warrior prove ground part'],
#  ['best refer book physic class th',
#   'book choos refer physic chemistri class cbse board'],
#  ['nation institut technolog kurukshetra social life nitk surathk',
#   'nation institut technolog karnataka nitk surathk graduat batch lesson would want give junior leav'],
#  ['best romant movi english', 'best romant movi ever seen'],
#  ['caus nightmar', 'caus nightmar seem real'],
#  ['abstract expression paint', 'major influenc abstract expression'],
#  ['print work', 'print work'],
#  ['like attend caltech jeremi ehrhardt', 'notabl folk attend caltech'],
#  ['harri becom horcrux', 'horcrux'],
#  ['best associ product manag apm program someon earli join learn product manag reward career compani',
#   'gener requir becom product manag program manag product base softwar compani'],
#  ['number skype alway busi', 'could get skype work android phone'],
#  ['realli war india pakistan uri attack effect', 'nuclear war india pakistan'],
#  ['ronald reagan manner speech', 'ronald reagan react'],
#  ['war strategi union confeder civil war',
#   'could confeder possibl defeat union forc gettysburg american civil war'],
#  ['best fiction novel', 'best fiction novel'],
#  ['recov email forgot password', 'forgot email password'],
#  ['recent demonetis result higher gdp much',
#   'demonetis could affect gdp india short run long run'],
#  ['ever heard travel hack', 'whatsapp hack'],
#  ['differ love piti', 'differ love piti'],
#  ['competit hire process republ bank', 'competit hire process bank'],
#  ['googl help spam rank adjust search result',
#   'distribut traffic googl organ search result e g vs rank first page vs second page'],
#  ['watch gonulcelen english subtitl', 'watch sarrainodu subtitl'],
#  ['usa power countri world', 'usa power countri world'],
#  ['obtain instant ulcer pain relief', 'better low back pain heat ice'],
#  ['think china food', 'think chines food'],
#  ['take advantag someon mean', 'wors take advantag someon materialist'],
#  ['cri happi sad', 'cri'],
#  ['girl like stick tongu take pictur',
#   'teen girl women gener allow boyfriend take nake pictur day digit age'],
#  ['find end novel depress', 'winston julia differ novel similar'],
#  ['mind blow comput tool exist peopl know',
#   'mind blow technolog exist peopl know'],
#  ['toothbrush wet dri appli toothpast', 'cheapest toothpast'],
#  ['question mark need imrov', 'ask question without get mark need improv'],
#  ['differ neutral state buffer state', 'everi state usa declar war would win'],
#  ['miner hold highest electr charg', 'miner hold greatest electr charg'],
#  ['greatest mysteri univers', 'greatest mysteri time'],
#  ['altern machin learn', 'sampl multi class imbal data set'],
#  ['china block sanction un jaish e mohammad jem chief masood azhar',
#   'china support masood azhar'],
#  ['mean futur budget', 'mean futur'],
#  ['excess amount vitamin c caus miscarriag', 'vitamin c caus miscarriag'],
#  ['like work asahi india glass pay scale one two year',
#   'get call letter get letter intent asahi india glass recruit'],
#  ['access torbox india', 'access googl com india'],
#  ['yakshini mantra', 'yantra mantra'],
#  ['six parti talk success', 'cours better nicmar'],
#  ['regist domain site email', 'regist domain'],
#  ['normal older men attract young women', 'attract older men'],
#  ['strongest structur strongest shape compress', 'strongest kevlar cord'],
#  ['rohingya muslim', 'rohingya peopl'],
#  ['matter whether human selfish evil', 'matter whether human evil'],
#  ['exocytosi endocytosi exampl activ passiv transport',
#   'exampl passiv transport cell'],
#  ['get hair bald head',
#   'shave head year get bald grew hair hair intial loos hair'],
#  ['ideal life retir', 'life retir'],
#  ['stanc pakistan',
#   'stanc pakistan possess weapon mass destruct north korea support dprk dprk'],
#  ['good websit escort', 'find good escort'],
#  ['one better polo diesel grand petrol', 'best diet grow decathlet'],
#  ['black hole mass', 'black hole finit mass'],
#  ['morgan freeman correct say way stop racism stop talk',
#   'view morgan freeman quot racism'],
#  ['fab current offer new employe stock option rsu',
#   'uber current offer new employe stock option rsu'],
#  ['would review site waveclu', 'good pay review site'],
#  ['mani way distribut ident look pencil student student get least one pencil',
#   'mani way appl distribut among children everi child get least appl'],
#  ['much would cost hire jerri seinfeld hour',
#   'much averag would cost video tape hour present'],
#  ['day late rabi vaccin possibl non bite exposur',
#   'take rabi inject day dog bite'],
#  ['mani year britain rule india', 'standard amount time given intern reloc'],
#  ['stop afraid work', 'stop afraid everyth'],
#  ['red keep key oitnb', 'red keep key season orang new black'],
#  ['age someon lose virgin', 'age lose virgin'],
#  ['forget', 'forget wife'],
#  ['could snoke secretli darth maul',
#   'could snoke darth plaguei kill emperor palpatin'],
#  ['monet youtub video upload copyright content chanc googl may block account',
#   'upload movi youtub monet issu copyright'],
#  ['would switch canon leica lux', 'tripod get canon'],
#  ['quora websit look like member quora moder', 'quora look moder'],
#  ['nobodi answer question quora', 'one answer question quora'],
#  ['funniest joke know', 'funniest joke time'],
#  ['got job offer chelmsford essex london pm pay tax deduct pl advic tent monthli expens coupl save possibl',
#   'leav norway pay mortgag bsu account sell apart without pay back tax deduct got bsu'],
#  ['stereotyp unit kingdom', 'american think unit kingdom'],
#  ['use twitter busi sourc', 'use twitter busi'],
#  ['transfer money skrill paypal account',
#   'send money paypal account skrill account withdraw'],
#  ['best earphon deep bass', 'best earphon rs'],
#  ['govern employe elig sukanya samrudi yojana', 'govern employe appli iec'],
#  ['correct look forward speak look forward speak', 'correct speak speak'],
#  ['best engin field', 'best field engin'],
#  ['make life suit stop life abus mental emot',
#   'emot abus peopl life sever ex boyfriend friend past cowork boss abus attract'],
#  ['differ gross salari ctc',
#   'seem differ weekli paycheck yearli salari employ agre upon work'],
#  ['prosper town kerala', 'mani christian kerala'],
#  ['best way gain confid', 'speak clariti confid'],
#  ['anyon see relat greek god hindu god',
#   'parallel draw god hindu mytholog greek mytholog egyptian mytholog etc'],
#  ['switch appl music spotifi', 'switch spotifi appl music'],
#  ['best fix incom fund', 'best fix incom fund'],
#  ['like live cologn', 'like live k ln germani'],
#  ['robert de niro al pacino success',
#   'regard best actor robert de niro al pacino'],
#  ['peopl prefer small famili', 'peopl prefer live small famili'],
#  ['anim kiss', 'anim besid human kiss'],
#  ['get delet instagram chat', 'view delet instagram dm'],
#  ['stop addict love', 'stop addict someon'],
#  ['hire two privat eye order follow',
#   'would abl hire two privat investig get follow'],
#  ['find startup acceler', 'startup acceler give fund'],
#  ['check wifi histori access android phone',
#   'cannot open quora wifi router access mobil network'],
#  ['signific battl somm battl compar contrast battl rostov',
#   'signific battl somm battl compar contrast battl riyadh'],
#  ['creativ colleg admiss essay read',
#   'colleg admiss offic cri public read applic essay'],
#  ['would happen cover one eye eye patch one year take patch',
#   'happen eye medicin enter eye'],
#  ['possibl pursu mani differ thing life', 'refus chose differ thing life'],
#  ['ben affleck shine christian bale batman',
#   'fanboy pleas true batman christian bale ben affleck'],
#  ['busi good start hyderabad', 'busi better start hyderabad'],
#  ['stop possess', 'stop possess person love'],
#  ['wife lord krishna', 'father lord krishna'],
#  ['best combin cours take along ca enhanc career',
#   'cours must taken along ca cours'],
#  ['take screenshot mac laptop', 'take screenshot macbook pro instruct'],
#  ['work execut recruit like', 'like work execut recruit'],
#  ['psycholog need collect fulfil', 'peopl collect thing'],
#  ['must watch tv show die', 'must watch tv show'],
#  ['becom fluent chines', 'becom fluent chines'],
#  ['effect demonit rupe note real estat sector',
#   'impact scrap rupe note real estat market'],
#  ['easiest way becom billionair', 'best way becom billionair'],
#  ['peopl will give free lectur conduct free workshop india colleg',
#   'almost two week prozac still feel antisoci still want go event social behavior mood chang daili'],
#  ['best way start learn robot',
#   'best way start robot best develop board start work'],
#  ['peopl hate hillari clinton', 'reason peopl dislik hillari clinton'],
#  ['women period regard unclean prevent take activ part ritual hinduism',
#   'alway expect woman take care housework children cook especi indian cultur activ respons women alon men share equal work'],
#  ['atheism lack belief god term belief god',
#   'atheism lack belief god claim god exist'],
#  ['like jack dorsey', 'jack dorsey like'],
#  ['best quot lesson assassin creed seri', 'assassin best robe assassin creed'],
#  ['inkjet printer use color ink print black white document',
#   'cmyk printer creat black use color ink complement black ink shop charg color print'],
#  ['creativ import', 'creativ import'],
#  ['hillari clinton could continu presidenti campaign would democrat parti choos new candid',
#   'hillari clinton longer serv democrat nomine would successor chosen'],
#  ['headphon work antenna play fm radio channel mobil phone mobil compani instal inbuilt antenna phone abl play fm without headphon',
#   'phone built fm antenna'],
#  ['best career growth technolog autom engin apart autom tool',
#   'himalayan duke ktm tour'],
#  ['disadvantag list compani nse', 'benefit list compani nse'],
#  ['mani deriv object posit respect time continu', 'draw becom fun'],
#  ['neutron star made', 'neutron star made neutron'],
#  ['got gpa enough get top univers like harvard', 'gpa suffici get top school'],
#  ['profit way trade binari option', 'binari option trade'],
#  ['util free time avoid depress',
#   'person graduat iim like lik even new iim like ranchi trichi ever catch graduat abc get similar packag'],
#  ['learn comput secur', 'get start learn inform secur'],
#  ['earn quora', 'earn money quora'],
#  ['puk code', 'puk tf simc'],
#  ['find job japan', 'find job japan'],
#  ['exampl sentenc use word hysteria',
#   'best home wireless network setup expect speed'],
#  ['anoth billion dollar lotteri jackpot',
#   'lotteri reach next billion dollar jackpot'],
#  ['scari drive road hana given turn',
#   'need four wheel drive car drive way road hana'],
#  ['creat new shell new termin use c program linux termin',
#   'creat new termin new shell linux use c program'],
#  ['cognit affect percept', 'cognit strain affect digest'],
#  ['tqwl differ ckwl tatkal wait list',
#   'made railway reserv got tatkal wait list get refund cancel'],
#  ['make world better place live futur gener', 'make world better place'],
#  ['mani champion leagu legend', 'best lol leagu legend champion'],
#  ['drink liter water day unhealthi', 'mani liter water drink run km daili'],
#  ['water great lake come lake wildlif compar lake prespa',
#   'water great lake come lake wildlif compar lake como'],
#  ['porn star watch porn', 'book ronda rousey star adult movi'],
#  ['trump support feel way walk back promis',
#   'trump support expect presid live promis forc sold'],
#  ['worri other opinion', 'care other opinion other think us'],
#  ['potti train month pitbul', 'potti train two month old labrador pup'],
#  ['jump rope five minut mani calori use', 'best way jump rope'],
#  ['onlin test seri best gate cs stream',
#   'test seri best gate comput scienc stream'],
#  ['best materi understand algorithm analysi newbi',
#   'math complet newbi need understand algorithm comput program book algorithm suitabl complet beginn'],
#  ['tempera bullmastiff huski mix', 'tempera corgi huski mix'],
#  ['ball weigh differ weight know heavier lighter find odd ball weigh',
#   'mani digit number form use mani'],
#  ['play raisin sun walter ad beneatha argu',
#   'raisin sun walter beneatha argu'],
#  ['sign ultra smart person play dumb', 'sign ultra smart peopl hide intellig'],
#  ['dark energi creat expans infinit creat',
#   'energi conserv expand univers potenti energi infinit energi creat infinit'],
#  ['get book publish', 'good way write publish book'],
#  ['disrupt bloomberg', 'disrupt bloomberg'],
#  ['flash run fast', 'flash dc charact fast flash run mile'],
#  ['best way invest legal get tangibl profit rel short period time say month',
#   'best invest next month'],
#  ['implement gst bill impact live common peopl',
#   'exactli gst bill exactli affect common peopl'],
#  ['recov gmail password', 'rememb password gmail account recov account'],
#  ['accur mental ill diagnos', 'accur diagnos medic mental ill'],
#  ['knee pain year old girl normal', 'normal year old girl spit blood'],
#  ['qualiti good leader', 'good qualiti leader'],
#  ['differ bay gulf strait', 'exactli differ sea bay'],
#  ['modi win', 'narendra modi becom prime minist india'],
#  ['open dmart store india franchis', 'get relianc digit store franchis'],
#  ['best youtub channel learn medicin', 'best youtub channel learn git'],
#  ['swami vivekananda ever eat non veg egg journey around world',
#   'hindu eat non veg'],
#  ['happen cancel tqwl ticket chart done', 'cancel tatkal wait list ticket'],
#  ['exactli common core initi standard pro con',
#   'pro con common core standard initi'],
#  ['choos journal publish paper', 'publish paper'],
#  ['new year resolut', 'creativ new year resolut'],
#  ['bad dream', 'get bad dream'],
#  ['slav squat', 'squat work men'],
#  ['mani mark score aiim rank', 'minimum mark score get among top aiim'],
#  ['oper room two surgeon equal experi disagre surgic procedur tie broken',
#   'doctor surgeon hold surgeri hour long rest oper'],
#  ['mani month take gain knowledg develop android app scratch',
#   'much time take learn android app develop scratch'],
#  ['love bodi guy', 'make whole bodi fair wheatish indian guy'],
#  ['right prison', 'prison right would'],
#  ['get free gem clash clan', 'get free gem clash clan'],
#  ['app like word len', 'word len use ocr'],
#  ['ex girlfriend suffer malaria deep urg visit placement idea',
#   'worri girlfriend text ex boyfriend till'],
#  ['best way get traffic websit', 'get traffic websit'],
#  ['feel someon upvot answer quora', 'feel see upvot answer quora'],
#  ['best film tv show featur strong femal protagonist',
#   'best femal strong charact film'],
#  ['far would go love wait one love ir move',
#   'thirteen year old best thing health'],
#  ['peopl die', 'peopl die'],
#  ['cloth made polyest instead cotton', 'cotton cloth made'],
#  ['bone marrow', 'bone marrow tast like'],
#  ['slave name reddic',
#   'ancient rome slave brand happen brand mark subsequ liber'],
#  ['long take dead bodi float surfac drown', 'dead bodi river long take float'],
#  ['get friend talk year still miss',
#   'get someon love broke last year still miss'],
#  ['travel new region better immers citi see mani citi cram',
#   'way explor world without spend money'],
#  ['make money onlin free cost', 'make money onlin'],
#  ['buy best qualiti custom cupcak gold coast',
#   'find delici cupcak gold coast'],
#  ['success odd even plan', 'success delhi odd even plan'],
#  ['war india pakistan win', 'win war start india pakistan'],
#  ['deal fear die', 'reduc fear die'],
#  ['would estim cost repair crack screen iphon',
#   'price pay repair broken iphon screen done'],
#  ['interest product innov mcdonald come', 'interest product innov ball come'],
#  ['end univers univers infinit', 'univers infinit end univers'],
#  ['cpagrip com', 'bestmytest com'],
#  ['much fund rais', 'much money rais'],
#  ['anna hazar think pm modi', 'peopl think mr arvind kejriw aap'],
#  ['effect ban note stock market india', 'effect ban rs rs note stock market'],
#  ['concentr contract differ eccentr contract',
#   'concentr eccentr contract compar contrast'],
#  ['puppet use yoda episod suck bad',
#   'peopl question news post opinion post social media websit'],
#  ['onlin platform post ad beer money opportun',
#   'onlin platform post ad beer money opportun'],
#  ['mean life', 'mean life'],
#  ['start small busi effect', 'start small busi construct'],
#  ['acquir posit moral', 'time deposit rd fd type time deposit'],
#  ['need friend', 'need friend'],
#  ['exist', 'exist'],
#  ['best hollywood thriller movi', 'best thriller movi hollywood'],
#  ['repeat nd year colleg find new colleg year cours',
#   'studi ashutosh colleg kolkata studi colleg india nd year'],
#  ['petrol diesel pump fill station use motor without ignit fire',
#   'happen fill petrol car diesel solut incid happen'],
#  ['job possibl exist bachelor homeland secur',
#   'job avail bachelor degre homeland secur'],
#  ['best book understand calculu', 'good book self studi calculu'],
#  ['break', 'break ex'],
#  ['use jio sim iphon', 'iphon support jio volt'],
#  ['unwritten rule usa', 'unwritten rule home'],
#  ['best answer two year gap job interview',
#   'best excus explain gap one two year job career job interview'],
#  ['best song low voic', 'song sweet airi mezzo voic'],
#  ['anyon predict birth chart', 'tell regard birth chart'],
#  ['birth trigonometr function', 'creator trigonometri'],
#  ['say mean trust everyth see even salt look like sugar',
#   'peopl say tri pleas other nice other mean pleas'],
#  ['countri prevent war', 'countri prevent war'],
#  ['becom billionair', 'becom billionair financ'],
#  ['learn web design', 'learn web design'],
#  ['best line calend schedul book system someth allow show avail custom request meet accept request appoint pop calendar remind autom',
#   'web servic send appoint sm remind custom extract data googl calendar'],
#  ['indian gdp affect ban rupe note',
#   'implic ban rupe currenc note indian economi'],
#  ['understand death philosoph', 'make understand death philosoph'],
#  ['dog consid omnivor', 'dog carnivor anim'],
#  ['like cheat upon relationship', 'like relationship someon cheat'],
#  ['know someon block text', 'turn user id text someon block'],
#  ['interest food eaten countri', 'delici dish ever eaten'],
#  ['like privat banker', 'like privat banker switzerland'],
#  ['journal', 'journal'],
#  ['one increas concentr', 'improv concentr'],
#  ['see sent invit linkedin pend invit',
#   'person linkedin invit think sent colleagu invit linkedin get chanc person'],
#  ['pro con german shepherd dog', 'pro con pet german shepherd'],
#  ['differ deism agnostic', 'differ hobbi habit'],
#  ['male porn star masturb ejacul',
#   'ok husband wife masturb togeth consid cheat partner masturb without consent'],
#  ['much cgpa requir get admiss mtech cse iit madra',
#   'get job consult firm mtech cse iit'],
#  ['biolog reason peopl cri emot', 'biolog reason cri'],
#  ['fact earth crust', 'earth core affect crust'],
#  ['isro use friction stir weld technolog',
#   'guy evalu current relationship feel worri temptat hang girl friend'],
#  ['wish simul fake locat app run io devic fake gp locat io without jailbreak non coder',
#   'fake iphon locat without jailbreak'],
#  ['would best way quit smoke', 'quit stop smoke'],
#  ['best program languag tc', 'best program languag'],
#  ['earthquak resist home', 'earthquak resist build work'],
#  ['kristen stewart bad actress', 'jennif lawrenc bad actress'],
#  ['japanes guy tri look feminin girl find gross',
#   'guy india becom desper know girl alway look relationship would hurt guy becom friend first'],
#  ['five popular sugar daddi websit', 'like date cougar sugar daddi'],
#  ['vtu st sem exam time tabl dec', 'frame time tabl month crack gate'],
#  ['best phone buy k', 'best mobil phone buy'],
#  ['start busi', 'start busi noth'],
#  ['best near death experi ever', 'anyon ever near death experi'],
#  ['keep get flea dog', 'keep dog get flea'],
#  ['year letter j come', 'letter j creat'],
#  ['harvard colleg cours gener shop advic turkish class',
#   'harvard colleg cours gener shop advic tamil class'],
#  ['send messag one android phone anoth android phone bluetooth',
#   'transfer contact one android phone anoth android phone'],
#  ['import book ever written', 'import book ever read'],
#  ['univers sigma design recruit new grad major look',
#   'univers sigma aldrich recruit new grad major look'],
#  ['phil india master uk psycholog',
#   'master student interest work humanitarian sector skill requir medic doctor master uk'],
#  ['univers powel industri recruit new grad major look',
#   'univers chart industri recruit new grad major look'],
#  ['best movi poster come across', 'best icon movi poster'],
#  ['exampl deuteromycota form', 'could bitcoin mine done singl raspberri pi'],
#  ['racist racist', 'racist'],
#  ['differ howev nevertheless', 'differ among'],
#  ['canada gees realli canadian', 'canadian call canada'],
#  ['find zero polynomi function math f x dfrac x x math',
#   'would find zero function math frac x x x math'],
#  ['edit devic googl play account', 'add second devic googl play account'],
#  ['becom good speaker', 'good speaker'],
#  ['write letter mr narendra modi', 'write narendra modi'],
#  ['elect gener presidenti elect donald trump ted cruz',
#   'delusion donald trump ted cruz'],
#  ['name bastard snow', 'jon snow ned bastard ladi catelyn hate much'],
#  ['think bermuda triangl', 'theori bermuda triangl'],
#  ['mexican girl like black guy', 'girl like black guy beard'],
#  ['live tini hous', 'would live tini hous'],
#  ['boy girl call year old year old year old year old',
#   'year old boy love girl year old live tamil nadu time propos'],
#  ['debeak cockerel month old', 'much feed month old raven'],
#  ['someon overcom anxieti', 'avoid depress anxieti'],
#  ['avoid whey yogurt', 'bad breath sign strong stomach'],
#  ['im love bisexu best friend also guy girlfriend want tell move',
#   'girl love best friend also girl'],
#  ['best univers germani ms', 'best univers germani get degre mechan engin'],
#  ['maintain peac mind', 'maintain peac mind'],
#  ['car good build qualiti india', 'volkswagen good reliabl car'],
#  ['massag one templ sooth migrain headach',
#   'caus effect way treat cure migrain headach'],
#  ['one better among kmc manip kmc mangalor',
#   'brief comparison kmc manip mangalor'],
#  ['bestfriend still ignor', 'bestfriend ignor'],
#  ['sensor avail acer liquid z android smart phone use cpu z app',
#   'use android phone app avail googl play store'],
#  ['keep motiv learn languag', 'keep motiv learn new languag'],
#  ['top assess compani india', 'top firm skill assess industri india global'],
#  ['mean emoticon', 'emoticon mean'],
#  ['pinkish discharg normal earli pregnanc caus', 'nichola piram cr'],
#  ['best way properli finger', 'would best way keep amus prison'],
#  ['scientist work', 'scientist work'],
#  ['mani sponsor candid shortlist cmc vellor',
#   'offic cultur woke patanjali offic haridwar'],
#  ['differ chines wed ceremoni western wed ceremoni',
#   'differ chines western style wed'],
#  ['condit tourism pakistan', 'prefer pg cours eee student tamil nadu'],
#  ['differ offshor onshor fund', 'differ offshor onshor'],
#  ['one hate shahrukh khan', 'peopl hate shahrukh khan peopl feel indian'],
#  ['best self help book ever read', 'top self help book read'],
#  ['evernot use', 'evernot use'],
#  ['titl continu gift magi', 'start continu gift magi'],
#  ['good song lyric prank best friend',
#   'good lyric prank song send best friend'],
#  ['argu gf made friend person hit said control freak want freedom',
#   'girl middl school best friend girl found bisexu tell best friend girl without freak chang whole friendship'],
#  ['pass drug test methamphetamin',
#   'hair dye help pass hair follicl drug test daili meth smoker'],
#  ['could start open sourc develop', 'start contribut open sourc project'],
#  ['dream look real', 'dream kind harm injuri real life'],
#  ['cricket player realli drink tea tea break',
#   'cricket actual drink tea tea break'],
#  ['get entri mit', 'requir select mit'],
#  ['fetu breath insid womb', 'fetu exhal womb'],
#  ['movi incest scene', 'good incest movi'],
#  ['sign guy feel crush want show hide',
#   'guy date never text feel like care see show like want feel way'],
#  ['accord intern feder robot mani robot exist',
#   'type belt use lift kg continu'],
#  ['oberon mad titania midsumm night dream',
#   'oberon punish titania midsumm night dream'],
#  ['regret divorc', 'ever regret divorc'],
#  ['much dna chang time clone year clone hair color',
#   'much person dna chang birth death life span approxim year'],
#  ['right tell girl feel', 'cool fact facebook'],
#  ['donald trump take cocain howard dean suggest',
#   'strong indic donald trump cocain'],
#  ['true order part elit rich success join secret organis otherwis chanc',
#   'syllabu ics geographi map'],
#  ['financi benefici firm teach architectur colleg',
#   'might career train program benefici colleg degre aspir entrepreneur tycoon'],
#  ['see comedi night kapil live show', 'way watch comedi night kapil live set'],
#  ['sandeep maheshwari quora', 'sandeep maheshwari'],
#  ['biggest monster monster hunter', 'monster hunter pc game'],
#  ['convinc peopl stop blasphem holi spirit',
#   'matter colleg graduat bcom admiss top indian b school even score high'],
#  ['stop watch porn', 'watch porn'],
#  ['start trust one', 'one learn trust'],
#  ['bucket list', 'bucket list'],
#  ['first come across porn', 'first introduc porn'],
#  ['car servic avail normal il good compar taxi rel',
#   'car servic avail atlanta good compar taxi rel'],
#  ['charg molecul pass lipid cell membran',
#   'sodium channel pass potassium channel'],
#  ['feel spous renown porn star', 'get rid feel spous cheat'],
#  ['best hostel book affili program', 'best non ac girl hostel srm'],
#  ['drive brooklyn staten island describ citi tourist attract compar queen',
#   'drive brooklyn staten island describ citi tourist attract compar tourist attract'],
#  ['eat everi day healthi', 'healthi eat whole avocado everi day'],
#  ['make free call famili member airtel andhra pradesh',
#   'get facebook badg notif htc'],
#  ['would hillari clinton elect', 'hillari clinton'],
#  ['use vick vapor rub stuffi nose', 'appli vick vapor rub treat stuffi nose'],
#  ['start prepar ugc net english literatur latest syllabu',
#   'prepar net jrf english literatur'],
#  ['earli european get protein columbian exchang',
#   'say breakfast portugues coffe introduc european portugues languag'],
#  ['best forum graphic design', 'best graphic design israel'],
#  ['alex jone satir show', 'canterburi tale satir'],
#  ['learn angularj instead angularj know typescript', 'start angular angularj'],
#  ['fall asleep day', 'fall asleep'],
#  ['marvel movi includ stan lee cameo', 'favourit stan lee cameo marvel film'],
#  ['view modi govern decis demonet rupe note affect economi',
#   'view ban rupe note india'],
#  ['label mad hatter hat mean', 'find figur label way textbook'],
#  ['wrote kar kid jingl', 'freelanc musician get jingl industri'],
#  ['saltwat taffi candi import greec', 'saltwat taffi candi import china'],
#  ['minimum requir enter mit', 'join mit'],
#  ['answer question quora', 'best thing ever learn quora'],
#  ['israel vs iran would win', 'israel iran went war would win'],
#  ['late learn piano', 'almost late learn piano'],
#  ['natur number', 'least natur number'],
#  ['one plu g volt enabl phone', 'phone buy moto one plu'],
#  ['enter new email id access recov facebook id',
#   'lost id adopt access origin birth certif replac id without even birth certif'],
#  ['travel faster light', 'possibl travel faster light'],
#  ['like firefight', 'like firefight'],
#  ['factor caus data inconsist distribut platform applic',
#   'main data platform'],
#  ['differ pocso sexual offens ipc', 'need ipc section'],
#  ['altern word', 'altern word creativ'],
#  ['consid illeg screen nba',
#   'shaquil neal consid tim duncan power forward therefor disqualifi duncan nba great big men discuss neal point'],
#  ['noth excit anymor regain excit', 'feel like excit someth noth excit'],
#  ['life lesson batman teach us', 'life lesson learn dark knight'],
#  ['stop crimin attempt kidnap escap unharm',
#   'stop crimin attempt kidnap escap unharm'],
#  ['sell amazon', 'start sell amazon'],
#  ['daniel ek expect spotifi india',
#   'daniel ek futur plan releas spotifi india'],
#  ['top book one read earli', 'book worth read earli'],
#  ['book start gate prepar', 'book start gate prepar'],
#  ['phrase love abid death exactli mean', 'phrase love beget love mean'],
#  ['similar share', 'similar share better'],
#  ['get high someon touch weed shake hand eat someth hand',
#   'someon grab shirt hand tell shut assault call polic'],
#  ['consid current trend inform technolog futur print media',
#   'model name see everywher'],
#  ['best recip chicken pizza', 'good pizza recip'],
#  ['good place learn mountain india',
#   'good mountain institut beginn level mountain cours'],
#  ['new tabl tenni ball damag rubber', 'unlock car tenni ball'],
#  ['new xbox one connect internet setup solut',
#   'withdraw money branch particular bank bank bank baroda atm card chequ book'],
#  ['wrong content life', 'cover stori'],
#  ['graviti theori',
#   'accord theori dimens dimens regard graviti address interstellar'],
#  ['could becom fighter pilot less requir eyesight',
#   'terribl eyesight still becom fighter pilot air forc'],
#  ['oper execut salari infosi',
#   'wake back bed lucid dream techniqu think restless leg syndrom regardless leg hurt night'],
#  ['cavemen scientif test', 'mythic creatur scientif test'],
#  ['climat chang revers', 'global climat chang revers halt'],
#  ['ask crush number', 'ask crush'],
#  ['believ gravit forc exist', 'gravit forc exist planet'],
#  ['mahabharata realli happen',
#   'mahabharata realli happen allegori accord k gandhi'],
#  ['congress stop presid start major war',
#   'good sourc purchas attorney email address thank'],
#  ['safe lose pound month', 'healthi lose pound month'],
#  ['cute shounen ai seri', 'pok mon seri end'],
#  ['polic light red blue', 'polic light red blue'],
#  ['post question mark need improv', 'question mark need improv'],
#  ['own natur', 'own natur factor'],
#  ['instal obb data file android',
#   'want instal exe extens file android mobil possibl'],
#  ['garbag valu get garbag valu c', 'garbag valu c'],
#  ['prepar softwar interview', 'best way prepar softwar interview'],
#  ['rahul gandhi chanc becom next pm india modi',
#   'rahul gandhi chanc becom next pm india modi'],
#  ['noon pm', 'good gym morn swim noon'],
#  ['differ comet asteroid', 'differ asteroid comet'],
#  ['chocol milk good', 'unrefriger milk good'],
#  ['studi', 'trick studi effect'],
#  ['countri best higher educ work', 'best countri higher educ usa uk'],
#  ['paint imag', 'paint'],
#  ['major highway california compar major highway tennesse',
#   'major highway california compar major highway texa'],
#  ['beyond univers', 'space expand new space come'],
#  ['grow hair physic chemic chang', 'bald person ever grow hair back'],
#  ['differ cultur histori', 'chili differ cultur'],
#  ['mean guy say like', 'mean guy say safe'],
#  ['make programm good', 'make good programm great'],
#  ['like caus world war iii', 'world war iii immin'],
#  ['civil war like us presidenti elect', 'us risk type upris elect'],
#  ['european countri best asylum seeker',
#   'best countri whistleblow seek asylum'],
#  ['crop circl get gener', 'crop circl'],
#  ['bake soda help pass urin test', 'bake soda help pass drug test'],
#  ['zika viru transmit', 'zika viru spread'],
#  ['best way learn algebra', 'learn algebra fast'],
#  ['feel retak class colleg', 'retak subject colleg affect futur job prospect'],
#  ['googl display network requir site seo page page optim first proceed gdn possibl',
#   'get name first page googl search'],
#  ['hard fake appear spiritu christian commun',
#   'battl agincourt happen compar battl edg hill'],
#  ['actinomorph flower', 'flower vaijanti'],
#  ['best place sex', 'best place sex'],
#  ['peopl anemia die younger', 'anemia increas irrit'],
#  ['feel new macbook pro late', 'get new macbook pro'],
#  ['cover head sleep caus brain damag',
#   'bing drink caus long term brain damag'],
#  ['major differ chines cultur western cultur', 'differ chines western cultur'],
#  ['scrape techniqu', 'good free web scraper scrape techniqu'],
#  ['old diabet type recent sugar level increas fast exercis eat whole grain happen',
#   'find best secur camera'],
#  ['healthi eat egg white everi day', 'healthi eat one chicken everi day'],
#  ['word rank highest dictionari com difficulti index',
#   'hindi word get place oxford dictionari'],
#  ['feel remors empathi', 'feel remors'],
#  ['mani minut cardio day', 'mani minut yoga done day'],
#  ['dog bite', 'dog bite'],
#  ['treat sever foot sprain', 'get sever foot sprain'],
#  ['sever crick neck treat', 'symptom sever crick neck'],
#  ['best place recommend foreign visit nepal', 'best place visit nepal'],
#  ['activ dlc skyrim laptop ive got work comput command line laptop use',
#   'tire laptop ive bought get old slow ish year desktop degrad quickli get solid state drive laptop desktop help increas longev'],
#  ['prepar hsbc glt placement test', 'compani choos hsbc glt cybag softwar'],
#  ['indian writer author ever use pen name',
#   'badli donald trump miscalcul run would brand valu'],
#  ['regist institut provid train variou program languag vocat cours exempt servic tax',
#   'much mark score ssc cpo get delhi polic'],
#  ['immin world war iii', 'head toward world war'],
#  ['write song', 'write song'],
#  ['could narendra modi next move demonet', 'next step demonet'],
#  ['want share share got', 'want share share get'],
#  ['interest fact know', 'interest fact peopl know'],
#  ['problem control fusion',
#   'develop fusion reactor capabl gener energi consum problem face'],
#  ['find ds emul android', 'work nintendo ds emul pc'],
#  ['want start cloth boutiqu india buy cheap wholesal cloth',
#   'buy cheap cloth bulk'],
#  ['becom true comput scienc engin', 'becom good comput scienc engin'],
#  ['necessari unlock bootload root android phone',
#   'clockworkmod work phone bootload unlock'],
#  ['bss engin',
#   'right option android develop becom translat year softwar develop field'],
#  ['get punish quora moder put israel judaism neg light',
#   'excel comput sciec program without wast four year cs degre indian engin colleg'],
#  ['lucid dream', 'experi lucid dream'],
#  ['feel like beauti', 'feel like attract desir mani'],
#  ['possibl ca th scienc',
#   'done appli ph fellowship govern institut clear tifr gs written test'],
#  ['hack someon whatsapp account', 'hack anoth whatsapp account'],
#  ['like studi math ucla', 'could usc buy ucla'],
#  ['best lesson life', 'import lesson learn life'],
#  ['interest mobil app', 'best mobil app recruit'],
#  ['trump presid affect indian student plan phd us',
#   'would trump presid affect indian student us'],
#  ['variou batman movi seri order', 'order batman arkham game'],
#  ['best daili life hack one use make life easi', 'hack daili life'],
#  ['much weight lose eat week', 'much weight lose purg everi time eat'],
#  ['favourit anim charact', 'favorit anim charact'],
#  ['atm machin work intern', 'atm transact work'],
#  ['mani mechan engin graduat india per year',
#   'mani mechan engin graduat per year india'],
#  ['start success privat equiti firm', 'need start privat equiti firm'],
#  ['underr date activ', 'underr activ'],
#  ['common fact everi mechan engin know', 'mechan engin student know'],
#  ['medium budget visit best place kerala three member day',
#   'best place visit kerala colleg student'],
#  ['quora digest fill question googl iq china',
#   'mani question iq question quora'],
#  ['would destroy world', 'destroy world'],
#  ['earn money youtub', 'make money youtub'],
#  ['differ particl molecul', 'entir turn syntax highlight sublim text golang'],
#  ['facebook add mutual friend',
#   'see order list peopl share mutual friend facebook'],
#  ['russian presid vladmir putin like person closest friend famili',
#   'putin becom public person rise fame like'],
#  ['start write', 'start write'],
#  ['time start big bang happen could big bang start time big bang start',
#   'big bang happen time happen'],
#  ['feel relationship singl life chang relationship',
#   'want stay singl life breakup feel like done seriou relationship thing'],
#  ['start civil servic exam prepar scratch', 'start prepar civil servic exam'],
#  ['non invas blood glucos monitor system abroad',
#   'non invas blood glucos monitor system india'],
#  ['differ pleasur masturb sex', 'differ sex masturb come pleasur'],
#  ['thing chang stay mean', 'peopl believ life end death'],
#  ['start solar energi busi egypt', 'start solar energi busi'],
#  ['pc spec gb ddr ram intel core duo ghz nvidia geforc gt gb ddr run assassin creed syndic gta v',
#   'web method futur year'],
#  ['psychic abil', 'psychic power'],
#  ['manag time studi', 'manag time work studi'],
#  ['academ calendar xlri', 'possibl give usmel step year gap'],
#  ['take urjit patel new rbi governor',
#   'urjit patel right person rbi governor'],
#  ['want presid', 'would want presid'],
#  ['india friendli relat neighbour countri', 'india relat u'],
#  ['trump voter care reneg campaign promis',
#   'trump support react realiz keep campaign promis'],
#  ['learn sleep', 'effici learn sleep'],
#  ['play asian playstat game european playstat',
#   'play asian playstat game european playstat'],
#  ['stop addict porn', 'stop watch porn'],
#  ['british engin manufactur skill declin dramat especi compar germani',
#   'uk bad live standard better'],
#  ['work machin learn research graduat',
#   'undergradu help machin learn research'],
#  ['futur io develop', 'futur io develop'],
#  ['mean life what purpos earth', 'feel purpos life'],
#  ['boyfriend', 'girl get boyfriend'],
#  ['time travel possibl', 'think time travel possibl'],
#  ['one get fuller face', 'get fuller face'],
#  ['late age think start career photographi',
#   'want start career photograph age late'],
#  ['best time sex', 'best time sex'],
#  ['weld steel aluminum togeth', 'steel aluminum weld togeth'],
#  ['youtub video highest like dislik ratio',
#   'possibl youtub video like dislik view'],
#  ['solut kashmir issu', 'possibl sharif govern resolv conflict kashmir'],
#  ['dug hole earth came side would happen',
#   'dug huge hole ground straight line would happen reach opposit side earth would head feet come first'],
#  ['creat free energi', 'make free energi'],
#  ['web design', 'web design'],
#  ['funniest highbrow joke ever heard', 'funniest joke stori ever heard'],
#  ['find phenotyp ratio', 'phenotyp ratio'],
#  ['saturn benefit hous sit slowli', 'time seem pass slowli bore lectur'],
#  ['academ qualifi bollywood celebr', 'bollywood celebr jet'],
#  ['differ qualiti wire wireless headphon',
#   'differ bose headphon ear around ear'],
#  ['movi everyon need watch least life', 'movi would recommend everyon watch'],
#  ['world war ever take place', 'world war immin expect'],
#  ['eat prune help constip', 'eat prune help constip'],
#  ['given statement correct unccd question cse prelim mani coach taken nd statement wrong',
#   'ever told condescend statement elder prove point question'],
#  ['would today technolog never realiz valu binari number har produc digit technolog',
#   'would world less technolog advanc two world war never occur'],
#  ['best way invest oil natur ga', 'minimum invest want buy oil ga royalti'],
#  ['arnab goswami pro bjp', 'quoran support modi'],
#  ['good sourc learn nuget', 'good sourc learn mathematica'],
#  ['would describ person lot interest', 'exampl describ person posit light'],
#  ['possibl turn indic light dahua camera', 'happen fli countri refus entri'],
#  ['barack obama import world', 'barack obama import world'],
#  ['reason pakistan support terror', 'pakistan becom safe global terror'],
#  ['stop hairfal', 'stop hairfal'],
#  ['opinion best classic song time', 'best classic music piec time'],
#  ['unusu aspect polit govern hungari', 'unusu aspect polit govern singapor'],
#  ['aim', 'aim scienc'],
#  ['respond boss fire via email', 'okay fire someon via email'],
#  ['cheap budget stay option north goa', 'nice budget place stay goa'],
#  ['websit similar quora', 'websit like quora'],
#  ['condit european refuge camp', 'condit insid european refuge camp'],
#  ['opposit homebird', 'opposit take'],
#  ['know fianc love', 'thing love fianc'],
#  ['somebodi explain problem step', 'somebodi explain step littl problem'],
#  ['develop presenc mind', 'increas presenc mind'],
#  ['mathemat fallaci wrong proof', 'would mathemat chang plu equal'],
#  ['help cibil score pay written amount',
#   'cibil score get impact pay minimum due amount'],
#  ['hobbit consid canon tolkien work',
#   'proper canon spell middl earth tolkien work'],
#  ['japanes think malaysian', 'malaysian think indian'],
#  ['har ki dun trek easi', 'take month babi base camp har ki dun trek'],
#  ['good websit learn c program begin', 'learn c program'],
#  ['suprem court decis play nation anthem movi screen affect patriot',
#   'view suprem court decis make play nation anthem mandatori cinema hall'],
#  ['unit state femal presid husband call first gentleman bill clinton call hillari elect',
#   'singl woman elect presid unit state would first ladi first gentleman'],
#  ['get mooc e learn onlin web video cours relat filmmak product develop indian professor',
#   'get mooc e learn onlin web video cours relat photographi develop indian professor'],
#  ['mobil number portabl final start may network provid realli agre',
#   'mobil number portabl final start may rd includ chang circl network provid realli agre'],
#  ['peopl hate twilight saga', 'peopl hate twilight much'],
#  ['believ imperi left posit neg legaci indian subcontin africa',
#   'step corpor life student feel'],
#  ['c best program languag', 'lua c one best program languag embed system'],
#  ['improv spoken english abil', 'improv english speak'],
#  ['gay sex', 'gay dislik gay sex'],
#  ['transfer school us curriculum take ibdp philippin school w percent averag grade system get gpa',
# ...
#  ['shift job e commerc cloud comput',
#   'comput scienc cours take want join product base e commerc compani'],
#  ['meet suresh raina', 'meet suresh raina'],
#  ['name song pictur madhuri dixit ranbir kapoor movi',
#   'name song salman khan teas madhuri dixit use slingshot movi'],
#  ['function nucleoplasm plant cell', 'function centrosom plant cell'],
#  ['fossil record use evid evolut', 'exampl evid evolut fossil record provid'],
#  ['hizmet movement', 'g len movement'],
#  ['could cat exam mat exam take place day th decemb',
#   'necessari learn vedic math spend time short trick cat exam'],
#  ['mythic creatur bibl', 'mythic creatur eat'],
#  ['one good oral anal vagin sex',
#   'consensu sex forc anal sex press charg fact consent sex vagin ruin case'],
#  ['winter weather condit like cincinnati oh', 'weather like winter tel aviv'],
#  ['stock best invest right', 'best stock invest long term right'],
#  ['improv read skill children', 'improv read skill'],
#  ['someon post porn video name', 'someon post porn video name'],
#  ['lose nutrient calori diarrhea', 'eat calori day make lose weight'],
#  ['safeti precaut handl shotgun propos nra alaska',
#   'safeti precaut handl shotgun propos nra arizona'],
#  ['benefit go walk everi morn',
#   'bollywood industri encourag outsid ex outsid may get one max two chanc wherea star kid get multipl chanc perform'],
#  ['martial artist start later life went becom champion',
#   'pro con bring small claim case peopl court tv'],
#  ['get ex back', 'ask ex get back togeth'],
#  ['framework choos cross platform mobil develop',
#   'cross platform choos develop mobil applic enterpris'],
#  ['best way prepar ielt', 'best way prepar ielt'],
#  ['know girl date onlin truli live real', 'know onlin girlfriend truli love'],
#  ['area game program mathemat involv suit math major',
#   'one go learn python abl appli area studi major chem minor math applic python could use appli job'],
#  ['differ larceni robberi', 'differ word burglari robberi'],
#  ['graph theori count prerequisit machin learn',
#   'graph theori nice cours machin learn'],
#  ['best school studi natur languag process india',
#   'best school studi natur languag process'],
#  ['ted cruz support vote donald trump',
#   'donald trump support ted cruz presid'],
#  ['gdp', 'signific gdp'],
#  ['blind trust provis american presid enforc', 'new american presid'],
#  ['make girl newli join junior colleg fall love', 'becom airlin pilot'],
#  ['home remedi pile anal fissur', 'cure anal fissur perman home remedi'],
#  ['mani word actual need learn gre correct method prepar gre verbal',
#   'get best score gre'],
#  ['soul immort', 'soul immort'],
#  ['person moon rd hous stori experi', 'person jupit st hous stori experi'],
#  ['done reduc pollut india', 'best way reduc pollut india'],
#  ['govern liasion legal india', 'ubermoto legal india'],
#  ['mean gotta take shit', 'fanci mean'],
#  ['best place celebr new year hyderabad',
#   'best place celebr new year hyderabad'],
#  ['work hard term studi', 'work hard term studi'],
#  ['upgrad window bit bit window',
#   'window bit upgrad bit window sinc free upgrad'],
#  ['bad experi life', 'good bad life experi'],
#  ['timbaland famou', 'brand drum timbaland use'],
#  ['get list individu telephon number', 'get cell phone number'],
#  ['wake rem sleep rememb dream',
#   'need wake middl rem sleep order rememb dream'],
#  ['common requir elect cours agricultur',
#   'common requir elect cours philosophi'],
#  ['learn sing', 'want learn sing start'],
#  ['capabl end googl monopoli search',
#   'googl virtual monopoli web search ever end'],
#  ['auto immun diseas caus insomnia', 'caus auto immun diseas'],
#  ['gta iv work window', 'gta iv work window'],
#  ['best ssc bank train insititut chandigarh',
#   'institut provid best ssc bank coach chandigarh'],
#  ['best pmp certif cours provid bangalor', 'best pmp certif center bangalor'],
#  ['differ net gross incom', 'differ gross incom versu net incom'],
#  ['wake earli morn', 'get earli morn'],
#  ['love', 'love'],
#  ['miss iit',
#   'expect join date accentur timelin show dec havent reciev updat organis'],
#  ['differ iphon iphon plu', 'differ iphon iphon'],
#  ['one improv credit score point',
#   'armi would win fight occur us troop ww us troop vietnam war'],
#  ['crush like back', 'sister told crush like without ask'],
#  ['power charact skyrim apart alduin', 'would win dovahkiin skyrim kylo ren'],
#  ['muslim guy date non muslim girl base religi individu factor',
#   'non muslim expect muslim'],
#  ['comment pictur', 'comment girlfriend pictur'],
#  ['road slipperi rain', 'rain precaut flood road'],
#  ['prove heisenberg uncertainti principl experiment',
#   'easiest way prove heisenberg uncertainti principl'],
#  ['ielt', 'ielt use'],
#  ['lose weight without sport', 'lose weight without exercis diet'],
#  ['digit camera shutter sound',
#   'digit camera electron shutter set make absolut sound nois'],
#  ['like date gangster', 'date man'],
#  ['main import polit caus world war', 'caus world war'],
#  ['get fear everyth', 'get fear'],
#  ['citi india best weather', 'citi argentina best weather'],
#  ['differ hdd ssd layman term', 'differ ssd hdd'],
#  ['mean dog vomit white foam', 'puppi vomit white foam'],
#  ['life hold signific world univers',
#   'truli purpos life creat purpos make feel signific vast world make feel exist vast world requir'],
#  ['job situat new zealand comput scienc graduat',
#   'job situat new zealand comput scienc graduat diploma'],
#  ['would develop e commerc websit', 'creat e commerc websit'],
#  ['get micro sim card iphon', 'iphon use micro sim card'],
#  ['improv question quora',
#   'question quora need improv best way ask question quora'],
#  ['one peopl catch feel establish friend benefit arrang drop feel go forward',
#   'age constantli see best peopl work live feel dissatisfi work live'],
#  ['tip someon tri teach sing', 'teach sing'],
#  ['climat chang scientist right worri much public relat packag',
#   'kind rude comment man get unit state date woman year younger'],
#  ['main reason problem india',
#   'franc farmer actress still around today would think donald trump'],
#  ['good substitut milk macaroni chees', 'good chees substitut havarti chees'],
#  ['constip caus dizzi', 'constip caus dizzi'],
#  ['possibl make doctor review app use patient share anonym treatment given doctor suggest medicin',
#   'warranti period mi ear headphon pro'],
#  ['pro con hillari clinton presid', 'pro con hillari clinton'],
#  ['best film take place one room', 'want get thrill movi watch'],
#  ['normal sperm shoot ejacul', 'ensur semen come peni ejacul'],
#  ['best coach center ssc bank chandigarh',
#   'best ssc bank coach center chandigarh'],
#  ['next number seri', 'would next number seri'],
#  ['best thing halloween', 'need best halloween'],
#  ['wish start invest equiti mutual fund open demat account best rate transact charg nri',
#   'want invest money stock market start'],
#  ['compani issu bonu share', 'compani issu bonu share'],
#  ['chang rupe note end black money india',
#   'think scrap rupe denomin go erad corrupt'],
#  ['major colleg leav unemploy engin law medicin',
#   'group discuss other keep fight let talk even ask let'],
#  ['best custom kiosk manufactur india', 'best manufactur custom kiosk india'],
#  ['telescop power enough view evid left behind nasa moon land',
#   'telescop power enough nowaday see man made object left moon apollo mission prove human fact land'],
#  ['architectur complex center forum hub anywher world third space',
#   'onlin softwar avail calcul time space complex java program big'],
#  ['mani keyword autohotkey script program languag latest version',
#   'mani keyword autoit script program languag latest version'],
#  ['hardest thing rais children ukrain', 'hardest thing rais children mexico'],
#  ['best sourc learn stock market onlin',
#   'best present softwar tube video make paid free'],
#  ['india sabotag badmouth econom project neighbour counri world',
#   'india alway sabotag badmouth econom project pakistan countri world'],
#  ['wet vagina feel like man', 'feel like ball vagina'],
#  ['thursday night footbal increas rate cb thursday night rather big bang theori',
#   'big bang theori tv seri popular popular mainstream viewer'],
#  ['grow taller', 'increas height'],
#  ['ever fire', 'ever fire deal'],
#  ['earth would dress like workout guy year summer',
#   'would dress like workout guru year summer'],
#  ['girlfriend stop talk', 'girlfriend talk'],
#  ['real estat look like scrape',
#   'abolish rs rs note affect real estat busi india'],
#  ['best interview question ever ask', 'best interview question ask'],
#  ['trust peopl quickli result alway betray trust peopl still hold relat simpl',
#   'think trust peopl wise enough betray someon els'],
#  ['best headhunt mumbai', 'best headhunt'],
#  ['dhp vaccin dog necessari', 'rabi vaccin human use dog'],
#  ['differ asia africa similar', 'differ cableway ropeway'],
#  ['wizard magic scientif test', 'mage scientif test'],
#  ['contract law import', 'maritim law import'],
#  ['moto g moto g rd gen get android nougat updat', 'long get os updat moto g'],
#  ['prove snr power snr voltag sequar',
#   'get paid fight companion jre fun exposur'],
#  ['best riddl riddler batman', 'best villain nolan batman film'],
#  ['much nuditi content game throne', 'much nuditi game throne tv seri'],
#  ['get follow comment blog', 'get follow blog'],
#  ['month ca cpt exam prepar', 'want crack ca cpt month studi'],
#  ['program languag learn want mmorpg game',
#   'program languag learn want develop game app'],
#  ['view recent demonet india', 'view demonet note india'],
#  ['cyru mistri remov', 'tata son replac cyru mistri ratan tata'],
#  ['cancel usaa auto insur', 'auto insur broker fee california'],
#  ['angri late', 'angri'],
#  ['form hypothesi sinc done test test result yet',
#   'peopl done master degre field advis master'],
#  ['consequ troll', 'consequ blackout'],
#  ['frighten arvind kejriw may kill shall',
#   'risk sell bitcoin accept credit card payment'],
#  ['disadvantag appl comput laptop brand',
#   'mani peopl us appl brand phone laptop'],
#  ['first moment rememb life', 'first thing rememb life'],
#  ['complet bd', 'complet bd'],
#  ['muslim hate narendra modi', 'muslim hate modi govern'],
#  ['', ''],
#  ['realli good famou romant comedi movi', 'best romant comedi movi'],
#  ['realist get second bachelor degre math intern student hold first bachelor degre accounnt',
#   'babi lion rais domest age human year surviv would releas wild'],
#  ['possibl believ old testament one god time believ triniti',
#   'search practic applic bit adc'],
#  ['start medit', 'start medit'],
#  ['infinit amount dark vacuum gravit energi creat expans',
#   'potenti energi vacuum energi virtual particl dark energi infinit merg'],
#  ['bihar realli develop mahagathbandhan sarkar',
#   'bihar develop leadership chief minist nitish kumar'],
#  ['homeopath medicin side effect', 'side effect homeopath medicin'],
#  ['determin good invest brokerag', 'best music player inr'],
#  ['scope suppli chain manag india',
#   'futur scope procur logist oper suppli chain manag'],
#  ['number piston equal number number cylind', 'join wikileak'],
#  ['post pictur social media', 'post pictur social media'],
#  ['control action dream', 'control dream dream wanna dream'],
#  ['manag long distanc relationship', 'long distanc relationship success'],
#  ['chanc could ask rich person million dollar actual give',
#   'hit million dollar shoot wrong think live expens area countri give better opportun'],
#  ['happen hong kong movi tv drama declin much',
#   'british citizen allow move eu live brexit happen'],
#  ['trump win elect', 'donald trump chanc win forthcom elect'],
#  ['best wallpap app iphon', 'best iphon wallpap'],
#  ['deactiv app app lock', 'recov photo app lock vault android mobil'],
#  ['format send book print', 'onlin test center busi'],
#  ['cast system still exist india',
#   'cast system exist india even decad independ'],
#  ['get boyfriend age', 'get boyfriend age'],
#  ['rank mark neet', 'rank neet mark'],
#  ['dynam flexi price harsh middl class peopl', 'seo smo help get busi'],
#  ['overdraft well fargo account', 'well fargo overdraft polici'],
#  ['new market techniqu languag school', 'market techniqu languag school'],
#  ['much olymp gold medalist earn', 'much olymp gold medalist earn china'],
#  ['easi way earn money onlin', 'earn money internet'],
#  ['reactanc capacitor', 'reason behind reactanc capacitor'],
#  ['true cost live sv bay area high new grad make k hard time find afford hous',
#   'amazon com reduc cost live high cost live area like silicon valley'],
#  ['best school world', 'best school world studi cinema'],
#  ['saltwat taffi candi import australia',
#   'saltwat taffi candi import austria'],
#  ['valu', 'zero factori equal one'],
#  ['best part time job bangalor', 'best part time job bangalor'],
#  ['becom attract girl', 'becom pretti attract'],
#  ['best music album ever', 'regard best music album'],
#  ['realist speak would happen usa donald trump win presid elect',
#   'donald trump support much happen win elect'],
#  ['symptom autism kid', 'symptom autism girl'],
#  ['like non smoke mother smoke children',
#   'like non smoke mother smoke children'],
#  ['life without dream', 'life dream realiti'],
#  ['comfort live washington dc salari', 'live comfort dc salari'],
#  ['find girl boyfriend', 'tell girl boyfriend'],
#  ['health benefit red lentil', 'benefit eat avocado'],
#  ['math relat work model class th', 'make work model math'],
#  ['could gain weight healthi way', 'gain healthi weight mass'],
#  ['kind anim', 'kind anim'],
#  ['anil ambani benefit rafel fighter jet deal', 'bought onlin'],
#  ['youtub red offlin featur good download video',
#   'possibl still decent credit rate chapter'],
#  ['know spous soulmat', 'know soulmat'],
#  ['get peopl person', 'peopl person'],
#  ['long distanc relationship work', 'long distanc relationship work'],
#  ['speak fluent english', 'understand english'],
#  ['consid posit secretari state gave insight us drone program reform target process',
#   'biggest challeng secretari state'],
#  ['exactli mike layman term', 'exactli framework layman term'],
#  ['buffalo like evolv band togeth lion cheetah instead run away',
#   'okha express provid food'],
#  ['find hacker good caus', 'find good hacker'],
#  ['chang snapdeal account mobil number',
#   'chang regist mobil number db bank account'],
#  ['tip make job interview process bank', 'tip make job interview process'],
#  ['main import export venezuela venezuela industri compar cuba',
#   'main import export venezuela venezuela industri compar bolivia'],
#  ['lucif gabriel relat', 'role cia nsc relat organ differ relat past'],
#  ['good movi watch', 'best movi watch'],
#  ['instal cydia without jailbreak io',
#   'download cydia devic without jailbreak'],
#  ['get job microsoft', 'get job googl microsoft'],
#  ['fahrenheit perceiv dystopia', 'fahrenheit book guy montag namesak'],
#  ['review love thought movi', 'review love rock movi'],
#  ['physic possibl travel back time', 'possibl travel back forward time'],
#  ['awkward peopl other', 'get sea breez summer rare winter'],
#  ['recov delet messag facebook', 'recov delet facebook messag'],
#  ['compens system uber', 'custom servic uber phone number'],
#  ['feasibl flipkart offer emi debit card differ factor involv',
#   'way purchas phone emi via flipkart debit card'],
#  ['defin task vs mileston vs deliver agil scrum methodolog',
#   'agil scrum model'],
#  ['life bore', 'life bore'],
#  ['buy meldonium canada', 'buy meldonium u'],
#  ['would cool way commit suicid', 'insan way commit suicid'],
#  ['accident took blood pressur medicin twice ok', 'ok blood pressur'],
#  ['paranorm experi', 'best paranorm experi'],
#  ['g band mhz sold g spectrum scam', 'exactli vyapam scam mani die'],
#  ['straight student motiv whatsoev go school someon help fight',
#   'fianc e die recent pain heart learn cope'],
#  ['best share purchas sale daili trade',
#   'sydney compani would best get advic busi sale purchas'],
#  ['girlfriend privat partstouch becom pregen', 'cosmet product price tag'],
#  ['could use cherenkov atmospher radiat gamma ray similar imag surfac planet ground base telescop',
#   'map surfac subsurfac planet use cosmic ray high frequenc gamma ray ground base telescop'],
#  ...]

# %%
train.columns
# Out:
# Index(['id', 'qid1', 'qid2', 'question1', 'question2', 'is_duplicate'], dtype='object')

# %%
corpus = [[0]*2]

# %%
quest0 = [train['question1'][0],train['question2'][0]]

# %%
corpus
# Out:
# [[0, 0]]

# %%
quest0 = re.sub('[^a-zA-Z]', ' ', quest0[0])

# %%
quest0 = quest0.lower()

# %%
quest0
# Out:
# 'what is the step by step guide to invest in share market in india '

# %%
quest0 = quest0.split()

# %%
quest0
# Out:
# ['what',
#  'is',
#  'the',
#  'step',
#  'by',
#  'step',
#  'guide',
#  'to',
#  'invest',
#  'in',
#  'share',
#  'market',
#  'in',
#  'india']

# %%
ps = PorterStemmer()

# %%
quest0 = [ps.stem(word) for word in quest0 if not word in set(stopwords.words('english'))]

# %%
quest0
# Out:
# ['step', 'step', 'guid', 'invest', 'share', 'market', 'india']
